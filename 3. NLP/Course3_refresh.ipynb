# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
sentences = [
    'I love my dog',
    'I love my cat',
    'You love my dog!',
    'Do you think my dog is amazing?'
]

# %%
tokenizer = Tokenizer(num_words=100, oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
word_index
# Out:
# {'<OOV>': 1,
#  'amazing': 11,
#  'cat': 7,
#  'do': 8,
#  'dog': 4,
#  'i': 5,
#  'is': 10,
#  'love': 3,
#  'my': 2,
#  'think': 9,
#  'you': 6}

# %%
sequences = tokenizer.texts_to_sequences(sentences)
sequences
# Out:
# [[5, 3, 2, 4], [5, 3, 2, 7], [6, 3, 2, 4], [8, 6, 9, 2, 4, 10, 11]]

# %%
padded = pad_sequences(sequences, maxlen=5)
padded
# Out:
# array([[ 0,  5,  3,  2,  4],
#        [ 0,  5,  3,  2,  7],
#        [ 0,  6,  3,  2,  4],
#        [ 9,  2,  4, 10, 11]], dtype=int32)

# %%
test_data = ["my dog is better than messi", "i love my mother"]
test_sequence = tokenizer.texts_to_sequences(test_data)
test_sequence
# Out:
# [[2, 4, 10, 1, 1, 1], [5, 3, 2, 1]]

# %%
padded_maxlen = pad_sequences(test_sequence, maxlen=10)
padded_maxlen
# Out:
# array([[ 0,  0,  0,  0,  2,  4, 10,  1,  1,  1],
#        [ 0,  0,  0,  0,  0,  0,  5,  3,  2,  1]], dtype=int32)
